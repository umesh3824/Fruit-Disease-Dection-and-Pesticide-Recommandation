# %%
import warnings
import os
import keras

import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

Generator = ImageDataGenerator()

# %% [markdown]
# ### Model For Checking Fruits Diseases

# %%
num_classes = 8

total_images=300

batch_size = 20

epochs = 100

steps_per_epoch=total_images//batch_size

path_to_test = "D:\dataset\\all\Test"
path_to_train = "D:\dataset\\all\Train"

train_data = Generator.flow_from_directory(path_to_train, (100, 100), batch_size=batch_size)
test_data = Generator.flow_from_directory(path_to_test, (100, 100), batch_size=batch_size)


model = Sequential()

model.add(Conv2D(16, (5, 5), input_shape=(100, 100, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(64, (5, 5),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(num_classes, activation="softmax"))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

ACCURACY_THRESHOLD = 0.95

class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > ACCURACY_THRESHOLD):
            self.model.stop_training = True

# Instantiate a callback object
callbacks = myCallback()



history=model.fit(train_data, steps_per_epoch=steps_per_epoch,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_data, validation_steps = 5,shuffle=False,callbacks=[callbacks])



model.save('AllCombine.h5')
# Out:
# Found 1018 images belonging to 8 classes.
# Found 288 images belonging to 8 classes.
# Epoch 1/100
# 15/15 [==============================] - 5s 268ms/step - loss: 9.5928 - accuracy: 0.3400 - val_loss: 1.8798 - val_accuracy: 0.3000
# Epoch 2/100
# 15/15 [==============================] - 3s 214ms/step - loss: 1.4339 - accuracy: 0.5267 - val_loss: 1.3025 - val_accuracy: 0.5000
# Epoch 3/100
# 15/15 [==============================] - 3s 172ms/step - loss: 1.1922 - accuracy: 0.5867 - val_loss: 1.2754 - val_accuracy: 0.5100
# Epoch 4/100
# 15/15 [==============================] - 3s 168ms/step - loss: 1.0604 - accuracy: 0.6367 - val_loss: 1.3177 - val_accuracy: 0.4800
# Epoch 5/100
# 15/15 [==============================] - 3s 170ms/step - loss: 0.8980 - accuracy: 0.6933 - val_loss: 1.1881 - val_accuracy: 0.5200
# Epoch 6/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.9874 - accuracy: 0.6367 - val_loss: 1.0537 - val_accuracy: 0.5900
# Epoch 7/100
# 15/15 [==============================] - 3s 173ms/step - loss: 0.8299 - accuracy: 0.6767 - val_loss: 1.1320 - val_accuracy: 0.5800
# Epoch 8/100
# 15/15 [==============================] - 3s 186ms/step - loss: 0.9089 - accuracy: 0.6833 - val_loss: 1.2960 - val_accuracy: 0.5300
# Epoch 9/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.9056 - accuracy: 0.6600 - val_loss: 1.0770 - val_accuracy: 0.5900
# Epoch 10/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.8719 - accuracy: 0.7100 - val_loss: 1.1472 - val_accuracy: 0.5600
# Epoch 11/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.7096 - accuracy: 0.7500 - val_loss: 1.0803 - val_accuracy: 0.6000
# Epoch 12/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.7934 - accuracy: 0.7033 - val_loss: 1.1788 - val_accuracy: 0.4900
# Epoch 13/100
# 15/15 [==============================] - 3s 179ms/step - loss: 0.8261 - accuracy: 0.7100 - val_loss: 1.4694 - val_accuracy: 0.5100
# Epoch 14/100
# 15/15 [==============================] - 2s 168ms/step - loss: 0.9697 - accuracy: 0.6867 - val_loss: 1.0529 - val_accuracy: 0.6200
# Epoch 15/100
# 15/15 [==============================] - 3s 190ms/step - loss: 0.7370 - accuracy: 0.7400 - val_loss: 1.4534 - val_accuracy: 0.4900
# Epoch 16/100
# 15/15 [==============================] - 3s 171ms/step - loss: 0.7339 - accuracy: 0.7633 - val_loss: 1.0886 - val_accuracy: 0.6400
# Epoch 17/100
# 15/15 [==============================] - 2s 158ms/step - loss: 0.7845 - accuracy: 0.7300 - val_loss: 1.0072 - val_accuracy: 0.5800
# Epoch 18/100
# 15/15 [==============================] - 3s 183ms/step - loss: 0.7723 - accuracy: 0.7167 - val_loss: 1.0932 - val_accuracy: 0.5700
# Epoch 19/100
# 15/15 [==============================] - 2s 168ms/step - loss: 0.7468 - accuracy: 0.7133 - val_loss: 1.1183 - val_accuracy: 0.5700
# Epoch 20/100
# 15/15 [==============================] - 3s 158ms/step - loss: 0.5214 - accuracy: 0.8167 - val_loss: 1.0270 - val_accuracy: 0.6900
# Epoch 21/100
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6959 - accuracy: 0.7667 - val_loss: 1.2713 - val_accuracy: 0.5400
# Epoch 22/100
# 15/15 [==============================] - 3s 173ms/step - loss: 0.6977 - accuracy: 0.7767 - val_loss: 1.3258 - val_accuracy: 0.5400
# Epoch 23/100
# 15/15 [==============================] - 3s 175ms/step - loss: 0.6512 - accuracy: 0.7733 - val_loss: 1.1384 - val_accuracy: 0.6100
# Epoch 24/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.7144 - accuracy: 0.7600 - val_loss: 1.0119 - val_accuracy: 0.6000
# Epoch 25/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.5865 - accuracy: 0.8000 - val_loss: 1.1408 - val_accuracy: 0.6400
# Epoch 26/100
# 15/15 [==============================] - 2s 166ms/step - loss: 0.6758 - accuracy: 0.7733 - val_loss: 1.2141 - val_accuracy: 0.5400
# Epoch 27/100
# 15/15 [==============================] - 3s 176ms/step - loss: 0.7846 - accuracy: 0.7267 - val_loss: 1.2330 - val_accuracy: 0.5600
# Epoch 28/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.6003 - accuracy: 0.7867 - val_loss: 1.1037 - val_accuracy: 0.6400
# Epoch 29/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.6250 - accuracy: 0.8000 - val_loss: 1.2371 - val_accuracy: 0.5600
# Epoch 30/100
# 15/15 [==============================] - 2s 160ms/step - loss: 0.4909 - accuracy: 0.8100 - val_loss: 1.1288 - val_accuracy: 0.6000
# Epoch 31/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.4777 - accuracy: 0.8400 - val_loss: 1.7754 - val_accuracy: 0.4700
# Epoch 32/100
# 15/15 [==============================] - 3s 174ms/step - loss: 0.5624 - accuracy: 0.8067 - val_loss: 1.4005 - val_accuracy: 0.5900
# Epoch 33/100
# 15/15 [==============================] - 3s 176ms/step - loss: 0.5362 - accuracy: 0.8000 - val_loss: 1.1704 - val_accuracy: 0.5900
# Epoch 34/100
# 15/15 [==============================] - 2s 168ms/step - loss: 0.4912 - accuracy: 0.8167 - val_loss: 1.0600 - val_accuracy: 0.7000
# Epoch 35/100
# 15/15 [==============================] - 2s 153ms/step - loss: 0.5130 - accuracy: 0.8200 - val_loss: 0.9656 - val_accuracy: 0.6400
# Epoch 36/100
# 15/15 [==============================] - 3s 185ms/step - loss: 0.4335 - accuracy: 0.8433 - val_loss: 1.2921 - val_accuracy: 0.6000
# Epoch 37/100
# 15/15 [==============================] - 3s 174ms/step - loss: 0.5913 - accuracy: 0.7967 - val_loss: 1.2562 - val_accuracy: 0.6000
# Epoch 38/100
# 15/15 [==============================] - 3s 177ms/step - loss: 0.5382 - accuracy: 0.8100 - val_loss: 1.1758 - val_accuracy: 0.6500
# Epoch 39/100
# 15/15 [==============================] - 3s 171ms/step - loss: 0.3675 - accuracy: 0.8767 - val_loss: 1.0701 - val_accuracy: 0.6200
# Epoch 40/100
# 15/15 [==============================] - 3s 175ms/step - loss: 0.4635 - accuracy: 0.8333 - val_loss: 1.4151 - val_accuracy: 0.6100
# Epoch 41/100
# 15/15 [==============================] - 3s 182ms/step - loss: 0.4561 - accuracy: 0.8267 - val_loss: 1.3543 - val_accuracy: 0.6800
# Epoch 42/100
# 15/15 [==============================] - 3s 183ms/step - loss: 0.4030 - accuracy: 0.8733 - val_loss: 1.2305 - val_accuracy: 0.6900
# Epoch 43/100
# 15/15 [==============================] - 3s 183ms/step - loss: 0.4448 - accuracy: 0.8467 - val_loss: 1.3082 - val_accuracy: 0.6400
# Epoch 44/100
# 15/15 [==============================] - 3s 192ms/step - loss: 0.3746 - accuracy: 0.8767 - val_loss: 1.6599 - val_accuracy: 0.5500
# Epoch 45/100
# 15/15 [==============================] - 3s 174ms/step - loss: 0.4369 - accuracy: 0.8267 - val_loss: 1.4205 - val_accuracy: 0.6200
# Epoch 46/100
# 15/15 [==============================] - 2s 162ms/step - loss: 0.4578 - accuracy: 0.8000 - val_loss: 1.1229 - val_accuracy: 0.6100
# Epoch 47/100
# 15/15 [==============================] - 3s 175ms/step - loss: 0.4072 - accuracy: 0.8800 - val_loss: 1.0667 - val_accuracy: 0.6900
# Epoch 48/100
# 15/15 [==============================] - 3s 168ms/step - loss: 0.3312 - accuracy: 0.8867 - val_loss: 1.2779 - val_accuracy: 0.6700
# Epoch 49/100
# 15/15 [==============================] - 2s 168ms/step - loss: 0.3854 - accuracy: 0.8900 - val_loss: 1.4994 - val_accuracy: 0.5500
# Epoch 50/100
# 15/15 [==============================] - 3s 172ms/step - loss: 0.2734 - accuracy: 0.9100 - val_loss: 1.3750 - val_accuracy: 0.6900
# Epoch 51/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.3278 - accuracy: 0.8933 - val_loss: 1.4400 - val_accuracy: 0.6300
# Epoch 52/100
# 15/15 [==============================] - 3s 176ms/step - loss: 0.6500 - accuracy: 0.7867 - val_loss: 1.3870 - val_accuracy: 0.5700
# Epoch 53/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4788 - accuracy: 0.8367 - val_loss: 1.2473 - val_accuracy: 0.5800
# Epoch 54/100
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4232 - accuracy: 0.8433 - val_loss: 1.3331 - val_accuracy: 0.6300
# Epoch 55/100
# 15/15 [==============================] - 2s 163ms/step - loss: 0.3193 - accuracy: 0.8767 - val_loss: 1.3771 - val_accuracy: 0.5700
# Epoch 56/100
# 15/15 [==============================] - 3s 186ms/step - loss: 0.3190 - accuracy: 0.9067 - val_loss: 1.6579 - val_accuracy: 0.5700
# Epoch 57/100
# 15/15 [==============================] - 3s 187ms/step - loss: 0.2987 - accuracy: 0.8867 - val_loss: 1.3662 - val_accuracy: 0.5900
# Epoch 58/100
# 15/15 [==============================] - 3s 178ms/step - loss: 0.3161 - accuracy: 0.9067 - val_loss: 1.3451 - val_accuracy: 0.6600
# Epoch 59/100
# 15/15 [==============================] - 3s 182ms/step - loss: 0.2068 - accuracy: 0.9400 - val_loss: 1.0379 - val_accuracy: 0.6900
# Epoch 60/100
# 15/15 [==============================] - 3s 181ms/step - loss: 0.1976 - accuracy: 0.9200 - val_loss: 1.4553 - val_accuracy: 0.6800
# Epoch 61/100
# 15/15 [==============================] - 3s 174ms/step - loss: 0.2116 - accuracy: 0.9300 - val_loss: 1.3270 - val_accuracy: 0.6800
# Epoch 62/100
# 15/15 [==============================] - 3s 174ms/step - loss: 0.2109 - accuracy: 0.9300 - val_loss: 1.8762 - val_accuracy: 0.6200
# Epoch 63/100
# 15/15 [==============================] - 3s 169ms/step - loss: 0.2472 - accuracy: 0.9133 - val_loss: 1.8706 - val_accuracy: 0.5800
# Epoch 64/100
# 15/15 [==============================] - 3s 181ms/step - loss: 0.2395 - accuracy: 0.9000 - val_loss: 1.7623 - val_accuracy: 0.6100
# Epoch 65/100
# 15/15 [==============================] - 2s 166ms/step - loss: 0.3394 - accuracy: 0.8833 - val_loss: 1.4477 - val_accuracy: 0.6600
# Epoch 66/100
# 15/15 [==============================] - 2s 166ms/step - loss: 0.2161 - accuracy: 0.9300 - val_loss: 1.7779 - val_accuracy: 0.6500
# Epoch 67/100
# 15/15 [==============================] - 3s 180ms/step - loss: 0.3276 - accuracy: 0.9000 - val_loss: 1.3117 - val_accuracy: 0.6600
# Epoch 68/100
# 15/15 [==============================] - 3s 174ms/step - loss: 0.1520 - accuracy: 0.9533 - val_loss: 1.5862 - val_accuracy: 0.6100

# %%
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs_range = range(epochs)

# plt.figure(figsize=(15, 7))
# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()

# %% [markdown]
# ### Model For Classification Fruits

# %%
num_classes = 2
total_images=1000
batch_size = 30
epochs = 20
steps_per_epoch=total_images//batch_size

path_to_test = "D:\BE\BE-DATA\SEM-1\BE Project\Dataset\\all\Test"
path_to_train = "D:\BE\BE-DATA\SEM-1\BE Project\Dataset\\all\Train"

train_data = Generator.flow_from_directory(path_to_train, (100, 100), batch_size=batch_size)
test_data = Generator.flow_from_directory(path_to_test, (100, 100), batch_size=batch_size)


model = Sequential()

model.add(Conv2D(16, (5, 5), input_shape=(100, 100, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(64, (5, 5),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(num_classes, activation="softmax"))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

ACCURACY_THRESHOLD = 0.97

class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > ACCURACY_THRESHOLD):
            self.model.stop_training = True

# Instantiate a callback object
callbacks = myCallback()



history=model.fit(train_data, steps_per_epoch=steps_per_epoch,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_data, validation_steps = 5,shuffle=False,callbacks=[callbacks])



model.save('AllClassification.h5')
# Out:
# Found 1007 images belonging to 2 classes.
# Found 288 images belonging to 2 classes.
# Epoch 1/20
# 33/33 [==============================] - 15s 432ms/step - loss: 9.7032 - accuracy: 0.5576 - val_loss: 0.6679 - val_accuracy: 0.5467
# Epoch 2/20
# 33/33 [==============================] - 7s 211ms/step - loss: 0.5236 - accuracy: 0.7465 - val_loss: 0.5367 - val_accuracy: 0.6800
# Epoch 3/20
# 33/33 [==============================] - 7s 208ms/step - loss: 0.3918 - accuracy: 0.8162 - val_loss: 0.3959 - val_accuracy: 0.7867
# Epoch 4/20
# 33/33 [==============================] - 7s 208ms/step - loss: 0.2727 - accuracy: 0.8747 - val_loss: 0.2720 - val_accuracy: 0.8667
# Epoch 5/20
# 33/33 [==============================] - 7s 201ms/step - loss: 0.2385 - accuracy: 0.8828 - val_loss: 0.2619 - val_accuracy: 0.8733
# Epoch 6/20
# 33/33 [==============================] - 6s 192ms/step - loss: 0.3008 - accuracy: 0.8737 - val_loss: 0.4220 - val_accuracy: 0.7867
# Epoch 7/20
# 33/33 [==============================] - 7s 201ms/step - loss: 0.2940 - accuracy: 0.8697 - val_loss: 0.2460 - val_accuracy: 0.8933
# Epoch 8/20
# 33/33 [==============================] - 6s 195ms/step - loss: 0.2066 - accuracy: 0.9061 - val_loss: 0.1600 - val_accuracy: 0.9400
# Epoch 9/20
# 33/33 [==============================] - 6s 197ms/step - loss: 0.2677 - accuracy: 0.8808 - val_loss: 0.3976 - val_accuracy: 0.8200
# Epoch 10/20
# 33/33 [==============================] - 6s 189ms/step - loss: 0.2160 - accuracy: 0.8970 - val_loss: 0.2112 - val_accuracy: 0.8933
# Epoch 11/20
# 33/33 [==============================] - 6s 191ms/step - loss: 0.1876 - accuracy: 0.9091 - val_loss: 0.2919 - val_accuracy: 0.8600
# Epoch 12/20
# 33/33 [==============================] - 7s 197ms/step - loss: 0.2022 - accuracy: 0.9212 - val_loss: 0.2922 - val_accuracy: 0.8733
# Epoch 13/20
# 33/33 [==============================] - 6s 191ms/step - loss: 0.2099 - accuracy: 0.9081 - val_loss: 0.2202 - val_accuracy: 0.9000
# Epoch 14/20
# 33/33 [==============================] - 6s 187ms/step - loss: 0.1916 - accuracy: 0.9222 - val_loss: 0.2534 - val_accuracy: 0.9067
# Epoch 15/20
# 33/33 [==============================] - 8s 228ms/step - loss: 0.1797 - accuracy: 0.9253 - val_loss: 0.2543 - val_accuracy: 0.8533
# Epoch 16/20
# 33/33 [==============================] - 7s 201ms/step - loss: 0.1732 - accuracy: 0.9111 - val_loss: 0.2120 - val_accuracy: 0.9267
# Epoch 17/20
# 33/33 [==============================] - 6s 191ms/step - loss: 0.1514 - accuracy: 0.9273 - val_loss: 0.2865 - val_accuracy: 0.8600
# Epoch 18/20
# 33/33 [==============================] - 6s 192ms/step - loss: 0.2799 - accuracy: 0.8919 - val_loss: 0.4183 - val_accuracy: 0.7733
# Epoch 19/20
# 33/33 [==============================] - 6s 186ms/step - loss: 0.2185 - accuracy: 0.9020 - val_loss: 0.2938 - val_accuracy: 0.8667
# Epoch 20/20
# 33/33 [==============================] - 6s 189ms/step - loss: 0.1473 - accuracy: 0.9374 - val_loss: 0.2422 - val_accuracy: 0.9067

# %%
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs_range = range(epochs)

# plt.figure(figsize=(15, 7))
# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()

# %% [markdown]
# ### Model For Disease detection for Apple

# %%
num_classes = 4
total_images=300
batch_size = 20
epochs = 100
steps_per_epoch=total_images//batch_size

path_to_test = "D:\BE\BE-DATA\SEM-1\BE Project\Dataset\\apple\Test"
path_to_train = "D:\BE\BE-DATA\SEM-1\BE Project\Dataset\\apple\Train"

train_data = Generator.flow_from_directory(path_to_train, (100, 100), batch_size=batch_size)
test_data = Generator.flow_from_directory(path_to_test, (100, 100), batch_size=batch_size)


model = Sequential()

model.add(Conv2D(16, (5, 5), input_shape=(100, 100, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(64, (5, 5),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(num_classes, activation="softmax"))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

ACCURACY_THRESHOLD = 0.95

class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > ACCURACY_THRESHOLD):
            self.model.stop_training = True

# Instantiate a callback object
callbacks = myCallback()


history=model.fit(train_data, steps_per_epoch=steps_per_epoch,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_data, validation_steps = 5,shuffle=False,callbacks=[callbacks])

model.save('Apple.h5')
# Out:
# Found 382 images belonging to 4 classes.
# Found 120 images belonging to 4 classes.
# Epoch 1/100
# 15/15 [==============================] - 6509s 465s/step - loss: 7.0899 - accuracy: 0.2933 - val_loss: 1.3141 - val_accuracy: 0.3800
# Epoch 2/100
# 15/15 [==============================] - 3s 213ms/step - loss: 1.2640 - accuracy: 0.4400 - val_loss: 1.3466 - val_accuracy: 0.3700
# Epoch 3/100
# 15/15 [==============================] - 3s 156ms/step - loss: 1.0569 - accuracy: 0.5933 - val_loss: 1.1434 - val_accuracy: 0.4600
# Epoch 4/100
# 15/15 [==============================] - 2s 151ms/step - loss: 1.1844 - accuracy: 0.4867 - val_loss: 1.0874 - val_accuracy: 0.5400
# Epoch 5/100
# 15/15 [==============================] - 2s 151ms/step - loss: 1.0372 - accuracy: 0.5500 - val_loss: 1.0326 - val_accuracy: 0.5200
# Epoch 6/100
# 15/15 [==============================] - 2s 148ms/step - loss: 0.9845 - accuracy: 0.6033 - val_loss: 1.1765 - val_accuracy: 0.4400
# Epoch 7/100
# 15/15 [==============================] - 2s 144ms/step - loss: 1.0057 - accuracy: 0.5500 - val_loss: 1.3685 - val_accuracy: 0.4200
# Epoch 8/100
# 15/15 [==============================] - 2s 136ms/step - loss: 0.9603 - accuracy: 0.6033 - val_loss: 1.1380 - val_accuracy: 0.5400
# Epoch 9/100
# 15/15 [==============================] - 2s 138ms/step - loss: 0.8792 - accuracy: 0.6800 - val_loss: 1.2231 - val_accuracy: 0.5400
# Epoch 10/100
# 15/15 [==============================] - 2s 155ms/step - loss: 1.0233 - accuracy: 0.6033 - val_loss: 1.1213 - val_accuracy: 0.5300
# Epoch 11/100
# 15/15 [==============================] - 2s 145ms/step - loss: 0.9382 - accuracy: 0.6767 - val_loss: 1.0643 - val_accuracy: 0.5900
# Epoch 12/100
# 15/15 [==============================] - 2s 142ms/step - loss: 0.7574 - accuracy: 0.7200 - val_loss: 1.1133 - val_accuracy: 0.5700
# Epoch 13/100
# 15/15 [==============================] - 2s 150ms/step - loss: 0.6376 - accuracy: 0.7633 - val_loss: 1.4133 - val_accuracy: 0.5300
# Epoch 14/100
# 15/15 [==============================] - 2s 131ms/step - loss: 0.6753 - accuracy: 0.7800 - val_loss: 1.3110 - val_accuracy: 0.5100
# Epoch 15/100
# 15/15 [==============================] - 2s 136ms/step - loss: 0.8033 - accuracy: 0.7100 - val_loss: 1.2642 - val_accuracy: 0.5300
# Epoch 16/100
# 15/15 [==============================] - 2s 141ms/step - loss: 0.7148 - accuracy: 0.7233 - val_loss: 1.5210 - val_accuracy: 0.5300
# Epoch 17/100
# 15/15 [==============================] - 2s 134ms/step - loss: 0.7187 - accuracy: 0.7167 - val_loss: 1.5472 - val_accuracy: 0.5000
# Epoch 18/100
# 15/15 [==============================] - 2s 151ms/step - loss: 0.8137 - accuracy: 0.7433 - val_loss: 2.0366 - val_accuracy: 0.5100
# Epoch 19/100
# 15/15 [==============================] - 2s 133ms/step - loss: 0.7160 - accuracy: 0.7200 - val_loss: 1.0014 - val_accuracy: 0.6200
# Epoch 20/100
# 15/15 [==============================] - 2s 145ms/step - loss: 0.6681 - accuracy: 0.7333 - val_loss: 1.2828 - val_accuracy: 0.5500
# Epoch 21/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.5049 - accuracy: 0.8200 - val_loss: 1.3514 - val_accuracy: 0.5600
# Epoch 22/100
# 15/15 [==============================] - 2s 135ms/step - loss: 0.4374 - accuracy: 0.8567 - val_loss: 1.4317 - val_accuracy: 0.5000
# Epoch 23/100
# 15/15 [==============================] - 2s 145ms/step - loss: 0.4644 - accuracy: 0.8467 - val_loss: 1.2727 - val_accuracy: 0.5900
# Epoch 24/100
# 15/15 [==============================] - 2s 131ms/step - loss: 0.3862 - accuracy: 0.8767 - val_loss: 1.6279 - val_accuracy: 0.5200
# Epoch 25/100
# 15/15 [==============================] - 2s 135ms/step - loss: 0.2786 - accuracy: 0.8833 - val_loss: 1.4860 - val_accuracy: 0.5700
# Epoch 26/100
# 15/15 [==============================] - 2s 165ms/step - loss: 0.3032 - accuracy: 0.8900 - val_loss: 1.6434 - val_accuracy: 0.6500
# Epoch 27/100
# 15/15 [==============================] - 2s 158ms/step - loss: 0.2397 - accuracy: 0.9200 - val_loss: 1.7029 - val_accuracy: 0.5900
# Epoch 28/100
# 15/15 [==============================] - 2s 159ms/step - loss: 0.2824 - accuracy: 0.9067 - val_loss: 1.7100 - val_accuracy: 0.5800
# Epoch 29/100
# 15/15 [==============================] - 2s 144ms/step - loss: 0.2829 - accuracy: 0.9367 - val_loss: 2.0771 - val_accuracy: 0.5300
# Epoch 30/100
# 15/15 [==============================] - 2s 142ms/step - loss: 0.3322 - accuracy: 0.8767 - val_loss: 1.7866 - val_accuracy: 0.5700
# Epoch 31/100
# 15/15 [==============================] - 2s 145ms/step - loss: 0.4071 - accuracy: 0.8433 - val_loss: 1.8044 - val_accuracy: 0.5300
# Epoch 32/100
# 15/15 [==============================] - 2s 130ms/step - loss: 0.3561 - accuracy: 0.9067 - val_loss: 1.6487 - val_accuracy: 0.5100
# Epoch 33/100
# 15/15 [==============================] - 2s 134ms/step - loss: 0.2990 - accuracy: 0.9000 - val_loss: 1.7052 - val_accuracy: 0.5600
# Epoch 34/100
# 15/15 [==============================] - 2s 141ms/step - loss: 0.2737 - accuracy: 0.9100 - val_loss: 1.7698 - val_accuracy: 0.5600
# Epoch 35/100
# 15/15 [==============================] - 2s 140ms/step - loss: 0.3396 - accuracy: 0.8933 - val_loss: 1.7213 - val_accuracy: 0.6000
# Epoch 36/100
# 15/15 [==============================] - 2s 147ms/step - loss: 0.2079 - accuracy: 0.9267 - val_loss: 1.8957 - val_accuracy: 0.5800
# Epoch 37/100
# 15/15 [==============================] - 2s 137ms/step - loss: 0.1254 - accuracy: 0.9600 - val_loss: 2.7832 - val_accuracy: 0.4800

# %%
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs_range = range(epochs)

# plt.figure(figsize=(15, 7))
# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()

# %% [markdown]
# ### Model For Disease detection for Guava

# %%
num_classes = 4
total_images=300
batch_size = 20
epochs = 100
steps_per_epoch=total_images//batch_size

path_to_test = "D:\BE\BE-DATA\SEM-1\BE Project\Dataset\\guava\Test"
path_to_train = "D:\BE\BE-DATA\SEM-1\BE Project\Dataset\\guava\Train"

train_data = Generator.flow_from_directory(path_to_train, (100, 100), batch_size=batch_size)
test_data = Generator.flow_from_directory(path_to_test, (100, 100), batch_size=batch_size)


model = Sequential()

model.add(Conv2D(16, (5, 5), input_shape=(100, 100, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(32, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(64, (5, 5),activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Conv2D(128, (5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=2))
model.add(Dropout(0.05))

model.add(Flatten())

model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.05))

model.add(Dense(num_classes, activation="softmax"))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(),
              metrics=['accuracy'])

ACCURACY_THRESHOLD = 0.94

class myCallback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > ACCURACY_THRESHOLD):
            self.model.stop_training = True

# Instantiate a callback object
callbacks = myCallback()


history=model.fit(train_data, steps_per_epoch=steps_per_epoch,
                    epochs=epochs,
                    verbose=1,
                    validation_data=test_data, validation_steps = 5,shuffle=False,callbacks=[callbacks])

model.save('Guava.h5')
# Out:
# Found 636 images belonging to 4 classes.
# Found 168 images belonging to 4 classes.
# Epoch 1/100
# 15/15 [==============================] - 7s 403ms/step - loss: 4.7227 - accuracy: 0.6033 - val_loss: 0.6430 - val_accuracy: 0.7100
# Epoch 2/100
# 15/15 [==============================] - 4s 262ms/step - loss: 0.4392 - accuracy: 0.7967 - val_loss: 0.6330 - val_accuracy: 0.6500
# Epoch 3/100
# 15/15 [==============================] - 3s 231ms/step - loss: 0.4002 - accuracy: 0.7833 - val_loss: 0.5873 - val_accuracy: 0.6700
# Epoch 4/100
# 15/15 [==============================] - 4s 260ms/step - loss: 0.4335 - accuracy: 0.7767 - val_loss: 0.6135 - val_accuracy: 0.6100
# Epoch 5/100
# 15/15 [==============================] - 3s 205ms/step - loss: 0.3898 - accuracy: 0.8333 - val_loss: 0.5473 - val_accuracy: 0.7100
# Epoch 6/100
# 15/15 [==============================] - 3s 205ms/step - loss: 0.2954 - accuracy: 0.8633 - val_loss: 0.4516 - val_accuracy: 0.8200
# Epoch 7/100
# 15/15 [==============================] - 3s 207ms/step - loss: 0.2573 - accuracy: 0.8900 - val_loss: 0.3836 - val_accuracy: 0.8100
# Epoch 8/100
# 15/15 [==============================] - 3s 207ms/step - loss: 0.4537 - accuracy: 0.8367 - val_loss: 0.8956 - val_accuracy: 0.6400
# Epoch 9/100
# 15/15 [==============================] - 3s 211ms/step - loss: 0.4508 - accuracy: 0.8233 - val_loss: 0.5932 - val_accuracy: 0.7600
# Epoch 10/100
# 15/15 [==============================] - 3s 202ms/step - loss: 0.3760 - accuracy: 0.8333 - val_loss: 0.7610 - val_accuracy: 0.7400
# Epoch 11/100
# 15/15 [==============================] - 3s 195ms/step - loss: 0.3369 - accuracy: 0.8233 - val_loss: 0.4527 - val_accuracy: 0.8000
# Epoch 12/100
# 15/15 [==============================] - 3s 194ms/step - loss: 0.3481 - accuracy: 0.8500 - val_loss: 0.5515 - val_accuracy: 0.7100
# Epoch 13/100
# 15/15 [==============================] - 3s 212ms/step - loss: 0.3301 - accuracy: 0.8300 - val_loss: 0.6134 - val_accuracy: 0.7000
# Epoch 14/100
# 15/15 [==============================] - 3s 213ms/step - loss: 0.3410 - accuracy: 0.8500 - val_loss: 0.4603 - val_accuracy: 0.7700
# Epoch 15/100
# 15/15 [==============================] - 3s 209ms/step - loss: 0.2825 - accuracy: 0.8700 - val_loss: 0.4787 - val_accuracy: 0.8000
# Epoch 16/100
# 15/15 [==============================] - 3s 217ms/step - loss: 0.2687 - accuracy: 0.9067 - val_loss: 0.4642 - val_accuracy: 0.7500
# Epoch 17/100
# 15/15 [==============================] - 3s 225ms/step - loss: 0.2326 - accuracy: 0.9100 - val_loss: 0.4373 - val_accuracy: 0.8100
# Epoch 18/100
# 15/15 [==============================] - 3s 216ms/step - loss: 0.2909 - accuracy: 0.8867 - val_loss: 0.3606 - val_accuracy: 0.8500
# Epoch 19/100
# 15/15 [==============================] - 3s 218ms/step - loss: 0.2076 - accuracy: 0.9233 - val_loss: 0.5721 - val_accuracy: 0.7700
# Epoch 20/100
# 15/15 [==============================] - 3s 215ms/step - loss: 0.3884 - accuracy: 0.8500 - val_loss: 0.4704 - val_accuracy: 0.8100
# Epoch 21/100
# 15/15 [==============================] - 3s 220ms/step - loss: 0.2834 - accuracy: 0.8467 - val_loss: 0.4706 - val_accuracy: 0.7600
# Epoch 22/100
# 15/15 [==============================] - 3s 205ms/step - loss: 0.2108 - accuracy: 0.9100 - val_loss: 0.5058 - val_accuracy: 0.7700
# Epoch 23/100
# 15/15 [==============================] - 3s 212ms/step - loss: 0.1865 - accuracy: 0.9100 - val_loss: 0.5450 - val_accuracy: 0.7700
# Epoch 24/100
# 15/15 [==============================] - 3s 233ms/step - loss: 0.2594 - accuracy: 0.8933 - val_loss: 0.5530 - val_accuracy: 0.7600
# Epoch 25/100
# 15/15 [==============================] - 3s 210ms/step - loss: 0.2699 - accuracy: 0.9000 - val_loss: 0.6776 - val_accuracy: 0.7600
# Epoch 26/100
# 15/15 [==============================] - 3s 206ms/step - loss: 0.2625 - accuracy: 0.8933 - val_loss: 0.6932 - val_accuracy: 0.7100
# Epoch 27/100
# 15/15 [==============================] - 3s 208ms/step - loss: 0.2327 - accuracy: 0.9033 - val_loss: 0.5534 - val_accuracy: 0.8100
# Epoch 28/100
# 15/15 [==============================] - 3s 206ms/step - loss: 0.1856 - accuracy: 0.9333 - val_loss: 0.5244 - val_accuracy: 0.8300
# Epoch 29/100
# 15/15 [==============================] - 3s 205ms/step - loss: 0.1734 - accuracy: 0.9367 - val_loss: 0.6448 - val_accuracy: 0.7800
# Epoch 30/100
# 15/15 [==============================] - 3s 216ms/step - loss: 0.2138 - accuracy: 0.9167 - val_loss: 0.4246 - val_accuracy: 0.8400
# Epoch 31/100
# 15/15 [==============================] - 3s 204ms/step - loss: 0.1793 - accuracy: 0.9233 - val_loss: 0.6558 - val_accuracy: 0.8000
# Epoch 32/100
# 15/15 [==============================] - 3s 211ms/step - loss: 0.1572 - accuracy: 0.9367 - val_loss: 0.4510 - val_accuracy: 0.8000
# Epoch 33/100
# 15/15 [==============================] - 3s 220ms/step - loss: 0.1107 - accuracy: 0.9700 - val_loss: 0.4989 - val_accuracy: 0.8500

# %%
# acc = history.history['accuracy']
# val_acc = history.history['val_accuracy']

# loss = history.history['loss']
# val_loss = history.history['val_loss']

# epochs_range = range(epochs)

# plt.figure(figsize=(15, 7))
# plt.subplot(1, 2, 1)
# plt.plot(epochs_range, acc, label='Training Accuracy')
# plt.plot(epochs_range, val_acc, label='Validation Accuracy')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')

# plt.subplot(1, 2, 2)
# plt.plot(epochs_range, loss, label='Training Loss')
# plt.plot(epochs_range, val_loss, label='Validation Loss')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.show()
